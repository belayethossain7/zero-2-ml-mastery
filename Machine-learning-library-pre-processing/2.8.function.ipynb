# %% [markdown]
# Functions
#
# Function is a block of code that can be reused in a Program
#
# Factorial of a number
#
# Factorial of anumber is the product of all the positive integers less than or eual to the given number.
#
#
# Factorial of 5 = 5*4*3*2*1=120

# %%
number = int(input(" Enter a number to find its factorial : "))

factorial= 1
if number==0:
  print("The factorial of o is 1")

else:
  for i in range(1, number+1):
    factorial = factorial*i

  print("the factorial of ",number," is ",factorial)
# Out:
#  Enter a number to find its factorial : 3
# the factorial of  3  is  6

# %% [markdown]
# Factorial function

# %%
def factorial_value(num):
  factorial=1

  if num==0:
    return factorial
  else:
    for i in range(1, num+1):
      factorial=factorial*i
    return factorial

# %%
print(factorial_value(3))
# Out:
# 6

# %% [markdown]
# print(number)

# %% [markdown]
# practice in function

# %%
def nad(name):
  print("greeting word for someone.")
  print("Hello",name)
  print("How are you",name)
  print("Hi",name)

# %%
nad("Belayet")
# Out:
# greeting word for someone.
# Hello Belayet
# How are you Belayet
# Hi Belayet

# %%
print(nad("Rio"))
# Out:
# greeting word for someone.
# Hello Rio
# How are you Rio
# Hi Rio
# None

# %%
number=int(input("Enter a number of find out its factorial : "))

factorial = 1;

if (number == 0):
  print("factorial of 0 is 1")

else:
  for i in range(1,number+1):
    factorial = factorial*i
  print("factorial of ",number," is ",factorial)
# Out:
# Enter a number of find out its factorial : 3
# factorial of  3  is  6

# %%
def number(num):
  factorial =1
  if (num==0):
    print("factorial of 0 is 1")
  else:
    for i in range(1,num+1):
      factorial = factorial*i
    print("factial of ",num," is ",factorial)

# %%
number(3)
# Out:
# factial of  3  is  6

# %%
print(number(3))
# Out:
# factial of  3  is  6
# None

# %%
print(factorial_value(3))
(nad("belayet"))
(number(5))
# Out:
# 6
# greeting word for someone.
# Hello belayet
# How are you belayet
# Hi belayet
# factial of  5  is  120

# %% [markdown]
# this is my observation _________---------_______
#
#
# if a function have return value , than when i call this type of funtion that time i used print function for this return type function
#
# if a function not use return type value that time we use or call a funtion, only function name .
