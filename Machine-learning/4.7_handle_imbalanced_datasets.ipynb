# %% [markdown]
# A dataset with an uneual class distribution..
#
# like daiabetes dataset -- who have diabetes that 1000 dataset,,this a class
#
# and who have not diabetes 100 datasets,,this is another class
#
#
# this is the uneual class distribution..thats why it is imblances dataset

# %%
# importing the dependencies

import numpy as np
import pandas as pd

# %%
# load the dataset to pandas dataframe
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
# first 5 rows of the dataframe
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# last five rows
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 25833  33785 -0.187402  0.445507  2.199225  3.030535 -0.361376  1.095100
# 25834  33785  1.237064  0.312096  0.191934  0.496764 -0.129777 -0.551625
# 25835  33785  1.245292 -0.594493  0.275982 -0.578346 -0.920599 -0.865570
# 25836  33787 -0.697373  0.401180  0.803750 -1.015524 -0.226100  0.283660
# 25837  33787  1.303469  0.498450       NaN       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 25833 -0.119594  0.245950 -0.371890  ...  0.154001  0.813468  0.377732
# 25834 -0.007160 -0.048880 -0.240393  ... -0.255114 -0.759423  0.072774
# 25835 -0.321689 -0.217249 -1.007295  ...  0.303333  0.736260 -0.102900
# 25836  0.094868  0.077613 -1.327124  ...  0.118688  0.467655 -0.162958
# 25837       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
## distribution of the two classes
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    25749
# 1.0       88
# Name: count, dtype: int64

# %% [markdown]
# This is Highly Imblanced Dataset
#
#
# 0 ---> Legit Transactions
#
# 1 ---> fraudulent Transactions

# %%
# separating the legit and frudulent transaction

legit = credit_card_data[credit_card_data.Class == 0.0]
fraud = credit_card_data[credit_card_data.Class == 1.0]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (25749, 31)
# (88, 31)

# %% [markdown]
# Under-sampling
#
# Build a sample dataset containing similar distribution of legit & fraudulent transactions
#
#
# Number of fraudulent transactions ---> 88

# %%
#sampling
legit_sample = legit.sample(n=88)

# %%
print(legit_sample.shape)
# Out:
# (88, 31)

# %% [markdown]
# Concatenate the two datafrmaes

# %%
new_dataset = pd.concat([legit_sample,fraud], axis = 0) # axis = 0 means raw  wise concatanation work

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 16271  27667  1.178731 -0.225835  0.648331 -0.165576 -0.772182 -0.378800
# 12761  22380  1.226442 -0.195344 -0.806405 -0.112774  1.924189  3.667472
# 12986  22814 -1.098205  2.324090 -3.384120  1.950670  0.174650 -1.657224
# 22358  32202 -1.555871 -0.883869  1.815002 -1.543087 -0.866938 -0.446863
# 15445  26825  1.502426 -1.125059  0.141382 -1.580960 -1.257787 -0.325930
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 16271 -0.478785  0.187545  0.332925  ... -0.056660 -0.226102  0.155073
# 12761 -0.754027  0.819081  1.690690  ... -0.486104 -1.204176  0.029047
# 12986  0.077893  0.831789  0.689155  ... -0.271469 -0.486726  0.023386
# 22358 -1.064838  0.855759 -1.115758  ...  0.681578  1.233947 -0.059340
# 15445 -1.081447 -0.003792 -1.905753  ... -0.212743 -0.327161 -0.060104
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 18773  29753  0.269614  3.549755 -5.810353  5.809370  1.538808 -2.269219
# 18809  29785  0.923764  0.344048 -2.880004  1.721680 -3.019565 -0.639736
# 20198  30852 -2.830984  0.885657  1.199930  2.861292  0.321669  0.289966
# 23308  32686  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
# 23422  32745 -2.179135  0.020218 -2.182733  2.572046 -3.663733  0.081568
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 18773 -0.824203  0.351070 -3.759059  ...  0.371121 -0.322290 -0.549856
# 18809 -3.801325  1.299096  0.864065  ...  0.899931  1.481271  0.725266
# 20198  1.767760 -2.451050  0.069736  ...  0.546589  0.334971  0.172106
# 23308 -2.202318  0.555088 -2.033892  ...  0.262202 -0.633528  0.092891
# 23422  0.268049  0.660437 -2.374027  ...  1.026421  0.299614  1.656800
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    88
# 1.0    88
# Name: count, dtype: int64
